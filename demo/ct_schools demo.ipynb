# %% [markdown]
# ## Demo of ct_schools
#
# This input spreadsheet has schools spelled slightly differently from the way they appear in most state databases.
#
# Let's use the ct_schools package to convert them to a common spelling. We'll find that this involves some "guessing" and isn't perfect. We can determine how good our guesses are and focus on fixing just the weakest guesses. So there's always going to be some manual work, but a lot less.
#
# In this walkthrough, we will:
#
# 1. Import the messy excel sheet sheff_16_17.xlsx
# 2. Play around with ct_schools.closest
# 3. Add a column of name guesses
# 4. Add a column of each guess's fuzzy ratio
# 5. Find the questionable matches

# %%
import pandas as pd
from ct_schools.schools import closest

# %% [markdown]
# ### 1. Import the source data
#
# Here we pull the correct sheet from the excel workbook, and skip a few rows.
#
# The school column contains the school names, spelled inconsistently compared with other data sets.

# %%
# Here I do a bunch of cleaning in one step to get this data set down to a manageable number of nicely named columns.
# Describing these steps isn't the point of this notebook.
df = pd.read_excel("sheff_16_17.xlsx",
                   sheetname="DesegStandard_SheffSchools_All",
                   skiprows=3,
                   usecols=[1,8,9,10],
                   names=["school","students_total","students_bl","students_ri"])\
.dropna(subset=["school"])

df.head()
# Out:
#                                 school students_total students_bl students_ri
# 2  The Global Experience Magnet School            218         151          67
# 3    Wintonbury Early Childhood Magnet            323         181         142
# 4               Connecticut IB Academy            197         102          95
# 5           Betances Early Reading Lab            295         195         100
# 6                *Betances STEM Magnet            375         284          91

# %% [markdown]
# ### 2. Play around with ct_schools.closest
#
# ct_schools.closest uses a common list of ct schools that has some other info joined in, like school ID, that makes it really usefully for pulling in other school data.
#
# Below shows the output of a search for "Valley." The closest school found is called "Valley View School"

# %%
closest("Valley")
# Out:
#             School Name Organization Type  Organization Code  \
# 267  Valley View School    Public Schools            1130211
#
#                                             Location 1 Zipcode         Phone  \
# 267  81 High St.\nPortland, CT 06480\n(41.57868, -7...   06480  860-342-3131
#
#      PreKindergarten  Kindergarten  Grade 1  Grade 2     ...      Grade 9  \
# 267                1             1        1        0     ...            0
#
#      Grade 10  Grade 11  Grade 12      Student Open Date  \
# 267         0         0         0  01Jul1984 0:00:00.000
#
#      Interdistrict Magnet                      lat_lng       lat        lng  \
# 267                   0.0  ('41.57868', ' -72.626149')  41.57868 -72.626149
#
#      FUZZ_RATIO
# 267          50
#
# [1 rows x 26 columns]

# %% [markdown]
# We can get more than one result, say the closest five schools...

# %%
closest("Valley",lim=5)
# Out:
#                  School Name        Organization Type  Organization Code  \
# 267       Valley View School           Public Schools            1130211
# 441          Smalley Academy           Public Schools             891211
# 40     River Valley Services  State Agency Facilities            3370815
# 1178   Shepaug Valley School         Regional Schools            2120312
# 268   Pleasant Valley School           Public Schools            1320211
#
#                                              Location 1     Zipcode  \
# 267   81 High St.\nPortland, CT 06480\n(41.57868, -7...       06480
# 441   175 West St.\nNew Britain, CT 06051-1415\n(41....  06051-1415
# 40      P.O. Box 351, Leak Hall\nMiddletown, CT 06457\n       06457
# 1178  159 South Street\nWashington, CT 06793-0000\n(...  06793-0000
# 268   591 Ellington Rd.\nSouth Windsor, CT 06074-411...  06074-4118
#
#              Phone  PreKindergarten  Kindergarten  Grade 1  Grade 2  \
# 267   860-342-3131                1             1        1        0
# 441   860-225-8647                0             1        1        1
# 40    860-262-7009                0             0        0        0
# 1178  860-868-7326                0             0        0        0
# 268   860-610-0291                0             1        1        1
#
#          ...      Grade 9  Grade 10  Grade 11  Grade 12  \
# 267      ...            0         0         0         0
# 441      ...            0         0         0         0
# 40       ...            1         1         1         1
# 1178     ...            1         1         1         1
# 268      ...            0         0         0         0
#
#           Student Open Date  Interdistrict Magnet  \
# 267   01Jul1984 0:00:00.000                   0.0
# 441   01Jul1984 0:00:00.000                   0.0
# 40    01Jul2007 0:00:00.000                   0.0
# 1178  26Aug2013 0:00:00.000                   NaN
# 268   01Jul1984 0:00:00.000                   0.0
#
#                            lat_lng        lat        lng  FUZZ_RATIO
# 267    ('41.57868', ' -72.626149')  41.578680 -72.626149          50
# 441   ('41.677627', ' -72.771328')  41.677627 -72.771328          48
# 40                             NaN        NaN        NaN          44
# 1178  ('41.601715', ' -73.303104')  41.601715 -73.303104          44
# 268   ('41.811222', ' -72.597108')  41.811222 -72.597108          43
#
# [5 rows x 26 columns]

# %% [markdown]
# ### 3. Adding a name_guess column to our original sheet
#
# Now that we know how to use the closest() function, let's apply it to the entire dataset.
#
# I'll use a lambda function on the input column (df["school"])and call closest.
#
# Since closest returns an entire DataFrame, and we only want the "School Name" value from the first row, we'll index into it with the bracket notation.

# %%
df["guess_name"] = df["school"].apply(lambda x: closest(x).iloc[0]["School Name"])
df.head()
# Out:
#                                 school students_total students_bl students_ri  \
# 2  The Global Experience Magnet School            218         151          67
# 3    Wintonbury Early Childhood Magnet            323         181         142
# 4               Connecticut IB Academy            197         102          95
# 5           Betances Early Reading Lab            295         195         100
# 6                *Betances STEM Magnet            375         284          91
#
#                                  guess_name
# 2           Global Experience Magnet School
# 3  Wintonbury Early Childhood Magnet School
# 4                    Connecticut IB Academy
# 5  Betances Early Reading Lab Magnet School
# 6               Betances STEM Magnet School

# %% [markdown]
# ### 4. Add a column with fuzz values
#
# ct_schools.closest() relies on the fuzzywuzzy python library to compute how close our guesses are. Fuzzywuzzy produces a score from 0 to 100, with 100 being a perfect match.
#
# We want to see those scores so we can identify any questionable guesses in the next section.
#
# I'll use the same approach as in step 3, but isolate the "FUZZ_RATIO" column.

# %%
df["fuzz"] = df["school"].apply(lambda x: closest(x).iloc[0]["FUZZ_RATIO"])
df.head()
# Out:
#                                 school students_total students_bl students_ri  \
# 2  The Global Experience Magnet School            218         151          67
# 3    Wintonbury Early Childhood Magnet            323         181         142
# 4               Connecticut IB Academy            197         102          95
# 5           Betances Early Reading Lab            295         195         100
# 6                *Betances STEM Magnet            375         284          91
#
#                                  guess_name  fuzz
# 2           Global Experience Magnet School    94
# 3  Wintonbury Early Childhood Magnet School    90
# 4                    Connecticut IB Academy   100
# 5  Betances Early Reading Lab Magnet School    79
# 6               Betances STEM Magnet School    83

# %% [markdown]
# Now, I'll sort by fuzz scores to identify any that are really low (potentially bad guesses).

# %%
df.sort_values(by="fuzz").head(20)
# Out:
#                                                school students_total  \
# 29                                    GHAA [Full-Day]            469
# 30                                    GHAA [Half-Day]            242
# 32                                  GHAMAS [Half-Day]             43
# 35  ****Medical Professions and Teacher Preparatio...            574
# 71      *Bloomfield Agriscience and Technology Center            NaN
# 31                                        GHAA/Middle            327
# 72      Glastonbury Agriscience and Technology Center             89
# 73               Suffield Regional Agriscience Center            118
# 7                                   **Breakthrough II            272
# 36            MLC Magnet Global/International Studies            688
# 16              **Journalism and Media Magnet Academy            190
# 45                                  Riverside Academy            394
# 8                   Breakthrough Magnet, South Campus            360
# 23                        STEM Magnet at Annie Fisher            367
# 56                  Sarah J. Rawson Elementary School            394
# 19                 *Noah Webster Micro-Society Magnet            631
# 57                             Odyssey Charter School            328
# 21               R.J. Kinsella Magnet/Performing Arts            913
# 12            Environmental Sciences @ Mary M. Hooker            611
# 5                          Betances Early Reading Lab            295
#
#    students_bl students_ri                                         guess_name  \
# 29         304         165                                       Path Academy
# 30          69         173                        Nathan Hale-Ray High School
# 32           8          35                                     Chapman School
# 35         431         143                  Charter Oak International Academy
# 71         131           +                         Bloomfield School District
# 31         238          89                                 RHAM Middle School
# 72          28          61                        Glastonbury School District
# 73           9         109                           Suffield School District
# 7          219          53                      Breakthrough II Magnet School
# 36         515         173  Metropolitan Learning Center for Global and In...
# 16         171          19         Journalism and Media Academy Magnet School
# 45         292         102                                 The Bridge Academy
# 8          263          97                         Breakthrough Magnet School
# 23         208         159                       STEM Magnet at Fisher School
# 56         382          12                           Warren Elementary School
# 19         475         156                Webster Micro Society Magnet School
# 57         130         198                        Side By Side Charter School
# 21         667         246          Kinsella Magnet School of Performing Arts
# 12         416         195     Environmental Sciences Magnet at Hooker School
# 5          195         100           Betances Early Reading Lab Magnet School
#
#     fuzz
# 29    37
# 30    43
# 32    45
# 35    52
# 71    54
# 31    55
# 72    56
# 73    57
# 7     65
# 36    67
# 16    73
# 45    74
# 8     75
# 23    76
# 56    77
# 19    78
# 57    78
# 21    78
# 12    78
# 5     79

# %% [markdown]
# Note how the first 15 or so results need to be checked over by hand, but then they get pretty reliable.
#
# Let's take a look at the last 20 results, with the strongest fuzz scores.

# %%
df.sort_values(by="fuzz").tail(20)
# Out:
#                                                school students_total  \
# 39                            *Public Safety Academy             474
# 9          **Capital Community College Magnet Academy             56
# 22                Sport and Medical Sciences Academy             709
# 62                *A. I. Prince Technical High School            719
# 26    Academy of Aerospace and Engineering Elementary            389
# 4                              Connecticut IB Academy            197
# 65                        Vinal Technical High School            522
# 64                Howell Cheney Technical High School            624
# 63                E. C. Goodwin Technical High School            624
# 14            Hartford Magnet Trinity College Academy           1024
# 44                          Connecticut River Academy            454
# 43              University of Hartford Magnet School             455
# 42                   Two Rivers Magnet Middle School             658
# 40                  Reggio Magnet School of the Arts             437
# 38                                     Museum Academy            469
# 24  University High School of Science and Engineer...            431
# 25               Academy of Aerospace and Engineering            733
# 34  International Magnet School for Global Citizen...            470
# 20         Pathways Academy of Technology and Design             421
# 28                                 Discovery Academy             484
#
#    students_bl students_ri                                         guess_name  \
# 39         359         115                              Public Safety Academy
# 9           47           9           Capital Community College Magnet Academy
# 22         488         221                Sports and Medical Sciences Academy
# 62         655          64                 A. I. Prince Technical High School
# 26         212         177    Academy of Aerospace and Engineering Elementary
# 4          102          95                             Connecticut IB Academy
# 65         158         364                        Vinal Technical High School
# 64         234         390                Howell Cheney Technical High School
# 63         419         205                E. C. Goodwin Technical High School
# 14         768         256            Hartford Magnet Trinity College Academy
# 44         323         131                          Connecticut River Academy
# 43         333         122               University of Hartford Magnet School
# 42         407         251                    Two Rivers Magnet Middle School
# 40         287         150                   Reggio Magnet School of the Arts
# 38         339         130                                     Museum Academy
# 24         258         173  University High School of Science and Engineering
# 25         446         287               Academy of Aerospace and Engineering
# 34         288         182  International Magnet School for Global Citizen...
# 20         304         117          Pathways Academy of Technology and Design
# 28         279         205                                  Discovery Academy
#
#     fuzz
# 39    98
# 9     98
# 22    99
# 62    99
# 26   100
# 4    100
# 65   100
# 64   100
# 63   100
# 14   100
# 44   100
# 43   100
# 42   100
# 40   100
# 38   100
# 24   100
# 25   100
# 34   100
# 20   100
# 28   100

# %% [markdown]
# But wait, you say, most of those are exact matches. That's not fair.
#
# OK, let's drop all the exact matches and look at the next best matches.

# %%
df[df["fuzz"] < 100].sort_values(by="fuzz").tail(20)
# Out:
#                                                school students_total  \
# 12            Environmental Sciences @ Mary M. Hooker            611
# 5                          Betances Early Reading Lab            295
# 10               **Capital Preparatory Magnet Academy            554
# 17                  Montessori Magnet at Annie Fisher            336
# 51        *Dr. James H Naylor/CCSU Leadership Academy            643
# 6                               *Betances STEM Magnet            375
# 13                                 Great Path Academy            272
# 33                   Glastonbury-East Hartford Magnet            452
# 37                    Montessori Magnet School (CREC)            349
# 18                        Montessori Magnet at Moylan            304
# 3                   Wintonbury Early Childhood Magnet            323
# 15                    Hartford Prekindergarten Magnet            157
# 2                 The Global Experience Magnet School            218
# 27  CREC Ana Grace Academy of the Arts Elementary ...            405
# 41                   ***Two Rivers Magnet High School            408
# 11                         **Classical Magnet School             560
# 39                            *Public Safety Academy             474
# 9          **Capital Community College Magnet Academy             56
# 62                *A. I. Prince Technical High School            719
# 22                Sport and Medical Sciences Academy             709
#
#    students_bl students_ri                                       guess_name  \
# 12         416         195   Environmental Sciences Magnet at Hooker School
# 5          195         100         Betances Early Reading Lab Magnet School
# 10         462          92                Capital Preparatory Magnet School
# 17         193         143               Montessori Magnet at Fisher School
# 51         495         148                   Naylor/CCSU Leadership Academy
# 6          284          91                      Betances STEM Magnet School
# 13         184          88                        Great Path Academy at MCC
# 33         250         202          Glastonbury/East Hartford Magnet School
# 37         236         113                         Montessori Magnet School
# 18         206          98               Montessori Magnet at Moylan School
# 3          181         142         Wintonbury Early Childhood Magnet School
# 15          90          67           Hartford PreKindergarten Magnet School
# 2          151          67                  Global Experience Magnet School
# 27         285         120  Ana Grace Academy of the Arts Elementary School
# 41         311          97                    Two Rivers Magnet High School
# 11         430         130                          Classical Magnet School
# 39         359         115                            Public Safety Academy
# 9           47           9         Capital Community College Magnet Academy
# 62         655          64               A. I. Prince Technical High School
# 22         488         221              Sports and Medical Sciences Academy
#
#     fuzz
# 12    78
# 5     79
# 10    81
# 17    81
# 51    82
# 6     83
# 13    84
# 33    87
# 37    87
# 18    89
# 3     90
# 15    90
# 2     94
# 27    95
# 41    95
# 11    96
# 39    98
# 9     98
# 62    99
# 22    99

# %% [markdown]
# Pretty good, right?
